# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezash97/Machine-Learning-Course/blob/main/FirstProject/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df = pd.read_csv('/content/titanicdata.csv')
df.head()
# Out:
#    Survived  Pclass  Sex   Age
# 0         0       3    2  22.0
# 1         1       1    1  38.0
# 2         1       3    1  26.0
# 3         1       1    1  35.0
# 4         0       3    2  35.0

# %%
X = df[["Pclass", "Sex", "Age"]].values
Y = df[["Survived"]].values

# %%
import copy
import numpy as np



def normalize(X, column_numbers):

  normalized_X = copy.deepcopy(X)

  for column in column_numbers:

    selected_column = X[:, column]
    column_mean = np.mean(selected_column)
    column_std = np.std(selected_column)
    normalized_column = np.zeros(( selected_column.shape ))

    for  row_index, row in enumerate(selected_column):
      temp = ( row - column_mean) / column_std
      normalized_column[row_index] = temp


    normalized_column = normalized_column.reshape(normalized_column.shape[0])
    normalized_X[:, column] = normalized_column 

  
  return normalized_X

# %%
# test normalize function
u = normalize(X, [0, 1, 2])
print(u[:5, :])
# Out:
# [[ 0.82737724  0.73769513 -0.5924806 ]
#  [-1.56610693 -1.35557354  0.63878901]
#  [ 0.82737724 -1.35557354 -0.2846632 ]
#  [-1.56610693 -1.35557354  0.40792596]
#  [ 0.82737724  0.73769513  0.40792596]]

# %%
def preprocess(X, column_numbers, Y):

  preprocessed_X = np.ones((X.shape[0], X.shape[1] + 1)) # + 1 for bias
  preprocessed_X[:, 1:] = normalize(X, column_numbers)

  preprocessed_Y = np.where(Y==0, -1, Y)

  
  return preprocessed_X, preprocessed_Y

# %%
# test preprocess function
X, Y = preprocess(X, [0, 1, 2], Y)
print(X[:5, :], X.shape)
print(Y[:5, :], Y.shape)
# Out:
# [[ 1.          0.82737724  0.73769513 -0.5924806 ]
#  [ 1.         -1.56610693 -1.35557354  0.63878901]
#  [ 1.          0.82737724 -1.35557354 -0.2846632 ]
#  [ 1.         -1.56610693 -1.35557354  0.40792596]
#  [ 1.          0.82737724  0.73769513  0.40792596]] (891, 4)
# [[-1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [-1]] (891, 1)

# %%
def sigmoid(s):
  
  return  1 / (1 + np.exp(-s))

# %%
def gradient_decent(X, Y, weights):
  
  # gradient_Ein = np.zeros((weight.shape))
  number_of_samples = X.shape[0]
  number_of_features = X.shape[1]
  full_shape_weight = np.zeros((X.shape))
  
  for i in range(number_of_samples):
    for j in range(number_of_features):
      full_shape_weight[i, j] = np.dot(Y[i], X[i, j]) / ( 1 + np.exp( np.dot( Y[i], np.matmul(X[i, :], weights.T) ) ) )

  gradient_Ein = ( (-1/number_of_samples) * np.sum(full_shape_weight, axis=0) ).reshape((1, number_of_features))


  return gradient_Ein

# %%
# test gradient decent function
t = gradient_decent(X, Y, np.ones((1, 4)))
print(t.shape)
print(t)
# Out:
# (1, 4)
# [[0.28376502 0.29781415 0.47682321 0.14324062]]

# %%
def evaluate(predicted_y, actual_y):
  
  
  number_of_samples = actual_y.shape[0]
  TP, TN, FP, FN = 0, 0, 0, 0
  for i in range(number_of_samples):
    
    if actual_y[i] == 1 and predicted_y[i] == 1:
      TP += 1
    elif actual_y[i] == 1 and predicted_y[i] == -1:
      FN += 1
    elif actual_y[i] == -1 and predicted_y[i] == 1:
      FP += 1
    elif actual_y[i] == -1 and predicted_y[i] == -1:
      TN += 1
    else:
      pass

  return ( (TP + TN) / (TP + TN + FP + FN) ) * 100

# %%
def LogisticRegression(X, Y, X_validation, Y_validation, Learning_Rate, epoch_num):


  initial_weights = np.ones((1, X.shape[1]))
  number_of_samples = X.shape[0]
  weights = copy.deepcopy(initial_weights)

  for i in range(epoch_num+1):
    
    # update
    weights -= (Learning_Rate * gradient_decent(X, Y, weights))
    
    # evaluate based on validation set
    temp = np.matmul(X_validation, weights.T)
    # define vectorized sigmoid
    sigmoid_v = np.vectorize(sigmoid)
    predicted_probability = sigmoid_v(temp)
    
    prediction_temp = np.where(predicted_probability > 0.5, 1, predicted_probability)
    prediction = np.where(prediction_temp <= 0.5, -1, prediction_temp)

    

    accuracy = evaluate(prediction, Y_validation)
    print(" validation accuracy after ", i, " epochs : ", "%.2f" % accuracy)

  return weights

# %%
def shuffle_in_unison(a, b):
    assert len(a) == len(b)
    shuffled_a = np.empty(a.shape, dtype=a.dtype)
    shuffled_b = np.empty(b.shape, dtype=b.dtype)
    permutation = np.random.permutation(len(a))
    for old_index, new_index in enumerate(permutation):
        shuffled_a[new_index] = a[old_index]
        shuffled_b[new_index] = b[old_index]
    return shuffled_a, shuffled_b

# %%
def split(X, Y, train_percentage, validation_percentage, test_percentage):

  number_of_samples = X.shape[0]
  
  train_start_point = 0
  train_end_point = int((number_of_samples* (train_percentage/100)))

  validation_start_point = int((number_of_samples* (train_percentage/100)))
  validation_end_point = int((number_of_samples* (train_percentage/100)) + (number_of_samples* (validation_percentage/100)))

  test_start_point = int((number_of_samples* (train_percentage/100)) + (number_of_samples* (validation_percentage/100)))
  test_end_point = number_of_samples

  X_train = X[train_start_point:train_end_point]
  Y_train = Y[train_start_point:train_end_point]

  X_validation = X[validation_start_point:validation_end_point]
  Y_validation = Y[validation_start_point:validation_end_point]

  X_test = X[test_start_point:test_end_point]
  Y_test = Y[test_start_point:test_end_point]


  return X_train, Y_train, X_validation, Y_validation, X_test, Y_test

# %%
X, Y = shuffle_in_unison(X, Y)
X_train, Y_train, X_validation, Y_validation, X_test, Y_test = split(X, Y, 60, 20, 20)

# %%
print(X_train.shape, Y_train.shape, X_validation.shape, Y_validation.shape, X_test.shape, Y_test.shape)
# Out:
# (534, 4) (534, 1) (178, 4) (178, 1) (179, 4) (179, 1)

# %%
final_weights = LogisticRegression(X_train, Y_train, X_validation, Y_validation, 0.01, 5000)
# Out:
# Streaming output truncated to the last 5000 lines.
#  validation accuracy after  1  epochs :  16.29
#  validation accuracy after  2  epochs :  16.29
#  validation accuracy after  3  epochs :  16.29
#  validation accuracy after  4  epochs :  16.29
#  validation accuracy after  5  epochs :  16.29
#  validation accuracy after  6  epochs :  16.29
#  validation accuracy after  7  epochs :  16.29
#  validation accuracy after  8  epochs :  16.29
#  validation accuracy after  9  epochs :  16.29
#  validation accuracy after  10  epochs :  16.29
#  validation accuracy after  11  epochs :  16.29
#  validation accuracy after  12  epochs :  16.29
#  validation accuracy after  13  epochs :  16.29
#  validation accuracy after  14  epochs :  16.29
#  validation accuracy after  15  epochs :  16.29
#  validation accuracy after  16  epochs :  16.29
#  validation accuracy after  17  epochs :  16.29
#  validation accuracy after  18  epochs :  16.29
#  validation accuracy after  19  epochs :  16.29
#  validation accuracy after  20  epochs :  16.29
#  validation accuracy after  21  epochs :  16.85
#  validation accuracy after  22  epochs :  16.85
#  validation accuracy after  23  epochs :  16.85
#  validation accuracy after  24  epochs :  16.85
#  validation accuracy after  25  epochs :  16.85
#  validation accuracy after  26  epochs :  16.85
#  validation accuracy after  27  epochs :  16.29
#  validation accuracy after  28  epochs :  16.29
#  validation accuracy after  29  epochs :  16.29
#  validation accuracy after  30  epochs :  16.85
#  validation accuracy after  31  epochs :  16.85
#  validation accuracy after  32  epochs :  16.85
#  validation accuracy after  33  epochs :  17.42
#  validation accuracy after  34  epochs :  17.42
#  validation accuracy after  35  epochs :  17.42
#  validation accuracy after  36  epochs :  17.42
#  validation accuracy after  37  epochs :  17.42
#  validation accuracy after  38  epochs :  17.42
#  validation accuracy after  39  epochs :  17.42
#  validation accuracy after  40  epochs :  17.42
#  validation accuracy after  41  epochs :  17.42
#  validation accuracy after  42  epochs :  17.42
#  validation accuracy after  43  epochs :  17.42
#  validation accuracy after  44  epochs :  17.42
#  validation accuracy after  45  epochs :  17.42
#  validation accuracy after  46  epochs :  17.42
#  validation accuracy after  47  epochs :  17.42
#  validation accuracy after  48  epochs :  17.42
#  validation accuracy after  49  epochs :  17.42
#  validation accuracy after  50  epochs :  17.42
#  validation accuracy after  51  epochs :  17.42
#  validation accuracy after  52  epochs :  17.42
#  validation accuracy after  53  epochs :  17.42
#  validation accuracy after  54  epochs :  17.42
#  validation accuracy after  55  epochs :  17.42
#  validation accuracy after  56  epochs :  17.42
#  validation accuracy after  57  epochs :  17.42
#  validation accuracy after  58  epochs :  17.42
#  validation accuracy after  59  epochs :  17.98
#  validation accuracy after  60  epochs :  17.98
#  validation accuracy after  61  epochs :  17.98
#  validation accuracy after  62  epochs :  17.98
#  validation accuracy after  63  epochs :  17.98
#  validation accuracy after  64  epochs :  17.98
#  validation accuracy after  65  epochs :  17.98
#  validation accuracy after  66  epochs :  17.98
#  validation accuracy after  67  epochs :  17.98
#  validation accuracy after  68  epochs :  17.98
#  validation accuracy after  69  epochs :  17.98
#  validation accuracy after  70  epochs :  17.98
#  validation accuracy after  71  epochs :  17.98
#  validation accuracy after  72  epochs :  17.98
#  validation accuracy after  73  epochs :  17.98
#  validation accuracy after  74  epochs :  17.98
#  validation accuracy after  75  epochs :  17.98
#  validation accuracy after  76  epochs :  17.98
#  validation accuracy after  77  epochs :  18.54
#  validation accuracy after  78  epochs :  18.54
#  validation accuracy after  79  epochs :  18.54
#  validation accuracy after  80  epochs :  18.54
#  validation accuracy after  81  epochs :  18.54
#  validation accuracy after  82  epochs :  18.54
#  validation accuracy after  83  epochs :  18.54
#  validation accuracy after  84  epochs :  19.66
#  validation accuracy after  85  epochs :  19.66
#  validation accuracy after  86  epochs :  19.66
#  validation accuracy after  87  epochs :  19.66
#  validation accuracy after  88  epochs :  19.66
#  validation accuracy after  89  epochs :  19.66
#  validation accuracy after  90  epochs :  19.66
#  validation accuracy after  91  epochs :  19.66
#  validation accuracy after  92  epochs :  19.66
#  validation accuracy after  93  epochs :  19.66
#  validation accuracy after  94  epochs :  19.66
#  validation accuracy after  95  epochs :  20.22
#  validation accuracy after  96  epochs :  20.22
#  validation accuracy after  97  epochs :  20.22
#  validation accuracy after  98  epochs :  20.22
#  validation accuracy after  99  epochs :  20.22
#  validation accuracy after  100  epochs :  20.22
#  validation accuracy after  101  epochs :  20.22
#  validation accuracy after  102  epochs :  20.22
#  validation accuracy after  103  epochs :  20.22
#  validation accuracy after  104  epochs :  20.22
#  validation accuracy after  105  epochs :  20.22
#  validation accuracy after  106  epochs :  20.22
#  validation accuracy after  107  epochs :  20.22
#  validation accuracy after  108  epochs :  20.22
#  validation accuracy after  109  epochs :  20.22
#  validation accuracy after  110  epochs :  20.22
#  validation accuracy after  111  epochs :  21.35
#  validation accuracy after  112  epochs :  21.35
#  validation accuracy after  113  epochs :  21.35
#  validation accuracy after  114  epochs :  21.35
#  validation accuracy after  115  epochs :  21.35
#  validation accuracy after  116  epochs :  21.35
#  validation accuracy after  117  epochs :  21.35
#  validation accuracy after  118  epochs :  21.35
#  validation accuracy after  119  epochs :  21.35
#  validation accuracy after  120  epochs :  21.35
#  validation accuracy after  121  epochs :  21.35
#  validation accuracy after  122  epochs :  21.35
#  validation accuracy after  123  epochs :  21.35
#  validation accuracy after  124  epochs :  21.35
#  validation accuracy after  125  epochs :  21.35
#  validation accuracy after  126  epochs :  21.35
#  validation accuracy after  127  epochs :  21.35
#  validation accuracy after  128  epochs :  21.35
#  validation accuracy after  129  epochs :  21.35
#  validation accuracy after  130  epochs :  21.35
#  validation accuracy after  131  epochs :  21.35
#  validation accuracy after  132  epochs :  21.35
#  validation accuracy after  133  epochs :  21.35
#  validation accuracy after  134  epochs :  21.35
#  validation accuracy after  135  epochs :  21.91
#  validation accuracy after  136  epochs :  21.91
#  validation accuracy after  137  epochs :  21.91
#  validation accuracy after  138  epochs :  21.91
#  validation accuracy after  139  epochs :  21.91
#  validation accuracy after  140  epochs :  21.91
#  validation accuracy after  141  epochs :  21.91
#  validation accuracy after  142  epochs :  21.91
#  validation accuracy after  143  epochs :  21.91
#  validation accuracy after  144  epochs :  21.91
#  validation accuracy after  145  epochs :  21.91
#  validation accuracy after  146  epochs :  21.91
#  validation accuracy after  147  epochs :  21.91
#  validation accuracy after  148  epochs :  22.47
#  validation accuracy after  149  epochs :  22.47
#  validation accuracy after  150  epochs :  22.47
#  validation accuracy after  151  epochs :  22.47
#  validation accuracy after  152  epochs :  22.47
#  validation accuracy after  153  epochs :  22.47
#  validation accuracy after  154  epochs :  22.47
#  validation accuracy after  155  epochs :  22.47
#  validation accuracy after  156  epochs :  22.47
#  validation accuracy after  157  epochs :  22.47
#  validation accuracy after  158  epochs :  22.47
#  validation accuracy after  159  epochs :  22.47
#  validation accuracy after  160  epochs :  23.03
#  validation accuracy after  161  epochs :  23.03
#  validation accuracy after  162  epochs :  23.03
#  validation accuracy after  163  epochs :  23.03
#  validation accuracy after  164  epochs :  23.03
#  validation accuracy after  165  epochs :  23.03
#  validation accuracy after  166  epochs :  23.03
#  validation accuracy after  167  epochs :  23.03
#  validation accuracy after  168  epochs :  23.03
#  validation accuracy after  169  epochs :  23.03
#  validation accuracy after  170  epochs :  23.60
#  validation accuracy after  171  epochs :  24.16
#  validation accuracy after  172  epochs :  24.16
#  validation accuracy after  173  epochs :  24.16
#  validation accuracy after  174  epochs :  24.16
#  validation accuracy after  175  epochs :  24.16
#  validation accuracy after  176  epochs :  24.16
#  validation accuracy after  177  epochs :  24.16
#  validation accuracy after  178  epochs :  24.16
#  validation accuracy after  179  epochs :  24.72
#  validation accuracy after  180  epochs :  24.72
#  validation accuracy after  181  epochs :  24.72
#  validation accuracy after  182  epochs :  24.72
#  validation accuracy after  183  epochs :  24.72
#  validation accuracy after  184  epochs :  25.28
#  validation accuracy after  185  epochs :  25.28
#  validation accuracy after  186  epochs :  25.28
#  validation accuracy after  187  epochs :  25.28
#  validation accuracy after  188  epochs :  25.28
#  validation accuracy after  189  epochs :  25.28
#  validation accuracy after  190  epochs :  26.40
#  validation accuracy after  191  epochs :  26.40
#  validation accuracy after  192  epochs :  26.40
#  validation accuracy after  193  epochs :  26.40
#  validation accuracy after  194  epochs :  25.84
#  validation accuracy after  195  epochs :  25.84
#  validation accuracy after  196  epochs :  25.84
#  validation accuracy after  197  epochs :  25.84
#  validation accuracy after  198  epochs :  25.84
#  validation accuracy after  199  epochs :  25.84
#  validation accuracy after  200  epochs :  25.84
#  validation accuracy after  201  epochs :  25.84
#  validation accuracy after  202  epochs :  25.84
#  validation accuracy after  203  epochs :  25.84
#  validation accuracy after  204  epochs :  26.97
#  validation accuracy after  205  epochs :  26.97
#  validation accuracy after  206  epochs :  26.97
#  validation accuracy after  207  epochs :  26.97
#  validation accuracy after  208  epochs :  26.97
#  validation accuracy after  209  epochs :  27.53
#  validation accuracy after  210  epochs :  27.53
#  validation accuracy after  211  epochs :  27.53
#  validation accuracy after  212  epochs :  27.53
#  validation accuracy after  213  epochs :  27.53
#  validation accuracy after  214  epochs :  27.53
#  validation accuracy after  215  epochs :  27.53
#  validation accuracy after  216  epochs :  27.53
#  validation accuracy after  217  epochs :  28.09
#  validation accuracy after  218  epochs :  28.65
#  validation accuracy after  219  epochs :  28.65
#  validation accuracy after  220  epochs :  28.65
#  validation accuracy after  221  epochs :  28.65
#  validation accuracy after  222  epochs :  29.78
#  validation accuracy after  223  epochs :  29.78
#  validation accuracy after  224  epochs :  29.78
#  validation accuracy after  225  epochs :  29.78
#  validation accuracy after  226  epochs :  30.34
#  validation accuracy after  227  epochs :  30.34
#  validation accuracy after  228  epochs :  30.34
#  validation accuracy after  229  epochs :  30.34
#  validation accuracy after  230  epochs :  30.34
#  validation accuracy after  231  epochs :  30.34
#  validation accuracy after  232  epochs :  30.34
#  validation accuracy after  233  epochs :  30.90
#  validation accuracy after  234  epochs :  30.90
#  validation accuracy after  235  epochs :  30.90
#  validation accuracy after  236  epochs :  30.90
#  validation accuracy after  237  epochs :  30.90
#  validation accuracy after  238  epochs :  30.90
#  validation accuracy after  239  epochs :  30.90
#  validation accuracy after  240  epochs :  30.90
#  validation accuracy after  241  epochs :  30.90
#  validation accuracy after  242  epochs :  30.90
#  validation accuracy after  243  epochs :  30.90
#  validation accuracy after  244  epochs :  30.90
#  validation accuracy after  245  epochs :  32.02
#  validation accuracy after  246  epochs :  32.02
#  validation accuracy after  247  epochs :  32.02
#  validation accuracy after  248  epochs :  32.02
#  validation accuracy after  249  epochs :  32.02
#  validation accuracy after  250  epochs :  32.02
#  validation accuracy after  251  epochs :  32.02
#  validation accuracy after  252  epochs :  32.02
#  validation accuracy after  253  epochs :  32.58
#  validation accuracy after  254  epochs :  32.58
#  validation accuracy after  255  epochs :  32.58
#  validation accuracy after  256  epochs :  32.58
#  validation accuracy after  257  epochs :  32.58
#  validation accuracy after  258  epochs :  32.58
#  validation accuracy after  259  epochs :  32.58
#  validation accuracy after  260  epochs :  32.58
#  validation accuracy after  261  epochs :  32.58
#  validation accuracy after  262  epochs :  32.58
#  validation accuracy after  263  epochs :  32.58
#  validation accuracy after  264  epochs :  33.15
#  validation accuracy after  265  epochs :  33.15
#  validation accuracy after  266  epochs :  32.58
#  validation accuracy after  267  epochs :  32.58
#  validation accuracy after  268  epochs :  32.58
#  validation accuracy after  269  epochs :  32.58
#  validation accuracy after  270  epochs :  32.58
#  validation accuracy after  271  epochs :  32.58
#  validation accuracy after  272  epochs :  32.58
#  validation accuracy after  273  epochs :  32.58
#  validation accuracy after  274  epochs :  32.58
#  validation accuracy after  275  epochs :  32.58
#  validation accuracy after  276  epochs :  33.71
#  validation accuracy after  277  epochs :  33.71
#  validation accuracy after  278  epochs :  33.71
#  validation accuracy after  279  epochs :  33.71
#  validation accuracy after  280  epochs :  33.71
#  validation accuracy after  281  epochs :  33.71
#  validation accuracy after  282  epochs :  33.71
#  validation accuracy after  283  epochs :  33.71
#  validation accuracy after  284  epochs :  33.71
#  validation accuracy after  285  epochs :  33.71
#  validation accuracy after  286  epochs :  33.71
#  validation accuracy after  287  epochs :  35.39
#  validation accuracy after  288  epochs :  35.96
#  validation accuracy after  289  epochs :  35.96
#  validation accuracy after  290  epochs :  35.96
#  validation accuracy after  291  epochs :  35.96
#  validation accuracy after  292  epochs :  35.96
#  validation accuracy after  293  epochs :  36.52
#  validation accuracy after  294  epochs :  37.64
#  validation accuracy after  295  epochs :  37.64
#  validation accuracy after  296  epochs :  37.64
#  validation accuracy after  297  epochs :  37.64
#  validation accuracy after  298  epochs :  38.76
#  validation accuracy after  299  epochs :  38.76
#  validation accuracy after  300  epochs :  38.76
#  validation accuracy after  301  epochs :  38.76
#  validation accuracy after  302  epochs :  38.76
#  validation accuracy after  303  epochs :  38.76
#  validation accuracy after  304  epochs :  38.76
#  validation accuracy after  305  epochs :  39.89
#  validation accuracy after  306  epochs :  39.89
#  validation accuracy after  307  epochs :  39.89
#  validation accuracy after  308  epochs :  39.89
#  validation accuracy after  309  epochs :  40.45
#  validation accuracy after  310  epochs :  40.45
#  validation accuracy after  311  epochs :  40.45
#  validation accuracy after  312  epochs :  40.45
#  validation accuracy after  313  epochs :  40.45
#  validation accuracy after  314  epochs :  40.45
#  validation accuracy after  315  epochs :  40.45
#  validation accuracy after  316  epochs :  40.45
#  validation accuracy after  317  epochs :  40.45
#  validation accuracy after  318  epochs :  40.45
#  validation accuracy after  319  epochs :  40.45
#  validation accuracy after  320  epochs :  41.01
#  validation accuracy after  321  epochs :  41.01
#  validation accuracy after  322  epochs :  41.01
#  validation accuracy after  323  epochs :  41.01
#  validation accuracy after  324  epochs :  41.01
#  validation accuracy after  325  epochs :  41.01
#  validation accuracy after  326  epochs :  41.01
#  validation accuracy after  327  epochs :  41.01
#  validation accuracy after  328  epochs :  41.01
#  validation accuracy after  329  epochs :  41.01
#  validation accuracy after  330  epochs :  41.57
#  validation accuracy after  331  epochs :  41.57
#  validation accuracy after  332  epochs :  42.70
#  validation accuracy after  333  epochs :  42.70
#  validation accuracy after  334  epochs :  42.70
#  validation accuracy after  335  epochs :  42.70
#  validation accuracy after  336  epochs :  42.70
#  validation accuracy after  337  epochs :  43.82
#  validation accuracy after  338  epochs :  44.38
#  validation accuracy after  339  epochs :  44.38
#  validation accuracy after  340  epochs :  44.38
#  validation accuracy after  341  epochs :  46.07
#  validation accuracy after  342  epochs :  46.07
#  validation accuracy after  343  epochs :  46.07
#  validation accuracy after  344  epochs :  46.07
#  validation accuracy after  345  epochs :  46.63
#  validation accuracy after  346  epochs :  46.63
#  validation accuracy after  347  epochs :  46.63
#  validation accuracy after  348  epochs :  46.63
#  validation accuracy after  349  epochs :  46.63
#  validation accuracy after  350  epochs :  46.63
#  validation accuracy after  351  epochs :  47.19
#  validation accuracy after  352  epochs :  47.19
#  validation accuracy after  353  epochs :  47.19
#  validation accuracy after  354  epochs :  47.19
#  validation accuracy after  355  epochs :  47.19
#  validation accuracy after  356  epochs :  47.19
#  validation accuracy after  357  epochs :  47.19
#  validation accuracy after  358  epochs :  47.19
#  validation accuracy after  359  epochs :  47.19
#  validation accuracy after  360  epochs :  47.19
#  validation accuracy after  361  epochs :  47.19
#  validation accuracy after  362  epochs :  47.19
#  validation accuracy after  363  epochs :  47.19
#  validation accuracy after  364  epochs :  47.19
#  validation accuracy after  365  epochs :  47.75
#  validation accuracy after  366  epochs :  47.75
#  validation accuracy after  367  epochs :  47.75
#  validation accuracy after  368  epochs :  47.75
#  validation accuracy after  369  epochs :  47.75
#  validation accuracy after  370  epochs :  47.75
#  validation accuracy after  371  epochs :  47.75
#  validation accuracy after  372  epochs :  47.75
#  validation accuracy after  373  epochs :  47.75
#  validation accuracy after  374  epochs :  47.75
#  validation accuracy after  375  epochs :  47.75
#  validation accuracy after  376  epochs :  48.31
#  validation accuracy after  377  epochs :  48.31
#  validation accuracy after  378  epochs :  48.31
#  validation accuracy after  379  epochs :  48.31
#  validation accuracy after  380  epochs :  48.31
#  validation accuracy after  381  epochs :  48.88
#  validation accuracy after  382  epochs :  48.88
#  validation accuracy after  383  epochs :  48.88
#  validation accuracy after  384  epochs :  49.44
#  validation accuracy after  385  epochs :  49.44
#  validation accuracy after  386  epochs :  49.44
#  validation accuracy after  387  epochs :  49.44
#  validation accuracy after  388  epochs :  57.87
#  validation accuracy after  389  epochs :  57.87
#  validation accuracy after  390  epochs :  59.55
#  validation accuracy after  391  epochs :  59.55
#  validation accuracy after  392  epochs :  59.55
#  validation accuracy after  393  epochs :  59.55
#  validation accuracy after  394  epochs :  59.55
#  validation accuracy after  395  epochs :  60.11
#  validation accuracy after  396  epochs :  60.11
#  validation accuracy after  397  epochs :  60.67
#  validation accuracy after  398  epochs :  60.67
#  validation accuracy after  399  epochs :  61.24
#  validation accuracy after  400  epochs :  61.24
#  validation accuracy after  401  epochs :  61.24
#  validation accuracy after  402  epochs :  61.24
#  validation accuracy after  403  epochs :  61.24
#  validation accuracy after  404  epochs :  61.24
#  validation accuracy after  405  epochs :  61.24
#  validation accuracy after  406  epochs :  61.24
#  validation accuracy after  407  epochs :  61.24
#  validation accuracy after  408  epochs :  61.24
#  validation accuracy after  409  epochs :  61.80
#  validation accuracy after  410  epochs :  61.80
#  validation accuracy after  411  epochs :  61.80
#  validation accuracy after  412  epochs :  61.80
#  validation accuracy after  413  epochs :  61.80
#  validation accuracy after  414  epochs :  61.80
#  validation accuracy after  415  epochs :  61.80
#  validation accuracy after  416  epochs :  61.80
#  validation accuracy after  417  epochs :  61.80
#  validation accuracy after  418  epochs :  62.36
#  validation accuracy after  419  epochs :  62.36
#  validation accuracy after  420  epochs :  62.36
#  validation accuracy after  421  epochs :  62.92
#  validation accuracy after  422  epochs :  62.92
#  validation accuracy after  423  epochs :  62.92
#  validation accuracy after  424  epochs :  62.92
#  validation accuracy after  425  epochs :  64.04
#  validation accuracy after  426  epochs :  64.04
#  validation accuracy after  427  epochs :  65.17
#  validation accuracy after  428  epochs :  65.17
#  validation accuracy after  429  epochs :  65.17
#  validation accuracy after  430  epochs :  65.17
#  validation accuracy after  431  epochs :  65.17
#  validation accuracy after  432  epochs :  65.17
#  validation accuracy after  433  epochs :  65.17
#  validation accuracy after  434  epochs :  65.17
#  validation accuracy after  435  epochs :  65.17
#  validation accuracy after  436  epochs :  65.17
#  validation accuracy after  437  epochs :  65.17
#  validation accuracy after  438  epochs :  65.17
#  validation accuracy after  439  epochs :  65.17
#  validation accuracy after  440  epochs :  65.17
#  validation accuracy after  441  epochs :  65.17
#  validation accuracy after  442  epochs :  65.17
#  validation accuracy after  443  epochs :  65.17
#  validation accuracy after  444  epochs :  65.17
#  validation accuracy after  445  epochs :  65.73
#  validation accuracy after  446  epochs :  65.73
#  validation accuracy after  447  epochs :  65.73
#  validation accuracy after  448  epochs :  65.73
#  validation accuracy after  449  epochs :  65.73
#  validation accuracy after  450  epochs :  65.73
#  validation accuracy after  451  epochs :  65.73
#  validation accuracy after  452  epochs :  65.73
#  validation accuracy after  453  epochs :  65.73
#  validation accuracy after  454  epochs :  65.73
#  validation accuracy after  455  epochs :  65.73
#  validation accuracy after  456  epochs :  65.73
#  validation accuracy after  457  epochs :  65.73
#  validation accuracy after  458  epochs :  65.73
#  validation accuracy after  459  epochs :  65.73
#  validation accuracy after  460  epochs :  65.73
#  validation accuracy after  461  epochs :  65.73
#  validation accuracy after  462  epochs :  66.29
#  validation accuracy after  463  epochs :  66.29
#  validation accuracy after  464  epochs :  66.85
#  validation accuracy after  465  epochs :  66.85
#  validation accuracy after  466  epochs :  66.85
#  validation accuracy after  467  epochs :  66.85
#  validation accuracy after  468  epochs :  66.85
#  validation accuracy after  469  epochs :  66.85
#  validation accuracy after  470  epochs :  67.42
#  validation accuracy after  471  epochs :  67.42
#  validation accuracy after  472  epochs :  67.42
#  validation accuracy after  473  epochs :  67.42
#  validation accuracy after  474  epochs :  67.42
#  validation accuracy after  475  epochs :  67.42
#  validation accuracy after  476  epochs :  67.42
#  validation accuracy after  477  epochs :  67.42
#  validation accuracy after  478  epochs :  67.98
#  validation accuracy after  479  epochs :  67.98
#  validation accuracy after  480  epochs :  67.98
#  validation accuracy after  481  epochs :  67.98
#  validation accuracy after  482  epochs :  67.98
#  validation accuracy after  483  epochs :  67.98
#  validation accuracy after  484  epochs :  67.98
#  validation accuracy after  485  epochs :  67.98
#  validation accuracy after  486  epochs :  68.54
#  validation accuracy after  487  epochs :  68.54
#  validation accuracy after  488  epochs :  68.54
#  validation accuracy after  489  epochs :  68.54
#  validation accuracy after  490  epochs :  68.54
#  validation accuracy after  491  epochs :  68.54
#  validation accuracy after  492  epochs :  68.54
#  validation accuracy after  493  epochs :  69.10
#  validation accuracy after  494  epochs :  69.10
#  validation accuracy after  495  epochs :  69.10
#  validation accuracy after  496  epochs :  69.10
#  validation accuracy after  497  epochs :  69.10
#  validation accuracy after  498  epochs :  69.10
#  validation accuracy after  499  epochs :  69.10
#  validation accuracy after  500  epochs :  69.10
#  validation accuracy after  501  epochs :  69.66
#  validation accuracy after  502  epochs :  69.66
#  validation accuracy after  503  epochs :  69.66
#  validation accuracy after  504  epochs :  69.66
#  validation accuracy after  505  epochs :  69.66
#  validation accuracy after  506  epochs :  69.66
#  validation accuracy after  507  epochs :  69.66
#  validation accuracy after  508  epochs :  69.66
#  validation accuracy after  509  epochs :  69.10
#  validation accuracy after  510  epochs :  69.10
#  validation accuracy after  511  epochs :  69.10
#  validation accuracy after  512  epochs :  69.10
#  validation accuracy after  513  epochs :  69.10
#  validation accuracy after  514  epochs :  69.10
#  validation accuracy after  515  epochs :  69.10
#  validation accuracy after  516  epochs :  69.10
#  validation accuracy after  517  epochs :  69.10
#  validation accuracy after  518  epochs :  69.10
#  validation accuracy after  519  epochs :  68.54
#  validation accuracy after  520  epochs :  68.54
#  validation accuracy after  521  epochs :  68.54
#  validation accuracy after  522  epochs :  68.54
#  validation accuracy after  523  epochs :  68.54
#  validation accuracy after  524  epochs :  68.54
#  validation accuracy after  525  epochs :  68.54
#  validation accuracy after  526  epochs :  68.54
#  validation accuracy after  527  epochs :  68.54
#  validation accuracy after  528  epochs :  68.54
#  validation accuracy after  529  epochs :  68.54
#  validation accuracy after  530  epochs :  68.54
#  validation accuracy after  531  epochs :  68.54
#  validation accuracy after  532  epochs :  68.54
#  validation accuracy after  533  epochs :  68.54
#  validation accuracy after  534  epochs :  68.54
#  validation accuracy after  535  epochs :  69.10
#  validation accuracy after  536  epochs :  69.10
#  validation accuracy after  537  epochs :  69.10
#  validation accuracy after  538  epochs :  69.10
#  validation accuracy after  539  epochs :  69.10
#  validation accuracy after  540  epochs :  69.10
#  validation accuracy after  541  epochs :  69.10
#  validation accuracy after  542  epochs :  69.10
#  validation accuracy after  543  epochs :  69.10
#  validation accuracy after  544  epochs :  69.10
#  validation accuracy after  545  epochs :  69.10
#  validation accuracy after  546  epochs :  69.10
#  validation accuracy after  547  epochs :  69.10
#  validation accuracy after  548  epochs :  69.10
#  validation accuracy after  549  epochs :  69.10
#  validation accuracy after  550  epochs :  69.10
#  validation accuracy after  551  epochs :  69.10
#  validation accuracy after  552  epochs :  69.10
#  validation accuracy after  553  epochs :  69.10
#  validation accuracy after  554  epochs :  69.10
#  validation accuracy after  555  epochs :  69.10
#  validation accuracy after  556  epochs :  69.10
#  validation accuracy after  557  epochs :  69.10
#  validation accuracy after  558  epochs :  69.10
#  validation accuracy after  559  epochs :  69.10
#  validation accuracy after  560  epochs :  69.10
#  validation accuracy after  561  epochs :  69.10
#  validation accuracy after  562  epochs :  69.10
#  validation accuracy after  563  epochs :  69.10
#  validation accuracy after  564  epochs :  69.10
#  validation accuracy after  565  epochs :  69.10
#  validation accuracy after  566  epochs :  69.10
#  validation accuracy after  567  epochs :  69.10
#  validation accuracy after  568  epochs :  69.10
#  validation accuracy after  569  epochs :  69.10
#  validation accuracy after  570  epochs :  69.10
#  validation accuracy after  571  epochs :  69.10
#  validation accuracy after  572  epochs :  69.10
#  validation accuracy after  573  epochs :  69.66
#  validation accuracy after  574  epochs :  69.66
#  validation accuracy after  575  epochs :  69.66
#  validation accuracy after  576  epochs :  69.66
#  validation accuracy after  577  epochs :  69.66
#  validation accuracy after  578  epochs :  69.66
#  validation accuracy after  579  epochs :  69.66
#  validation accuracy after  580  epochs :  69.66
#  validation accuracy after  581  epochs :  69.66
#  validation accuracy after  582  epochs :  69.66
#  validation accuracy after  583  epochs :  70.22
#  validation accuracy after  584  epochs :  70.22
#  validation accuracy after  585  epochs :  70.22
#  validation accuracy after  586  epochs :  70.22
#  validation accuracy after  587  epochs :  70.22
#  validation accuracy after  588  epochs :  70.22
#  validation accuracy after  589  epochs :  70.22
#  validation accuracy after  590  epochs :  70.22
#  validation accuracy after  591  epochs :  70.22
#  validation accuracy after  592  epochs :  70.79
#  validation accuracy after  593  epochs :  70.79
#  validation accuracy after  594  epochs :  70.79
#  validation accuracy after  595  epochs :  70.79
#  validation accuracy after  596  epochs :  70.79
#  validation accuracy after  597  epochs :  70.79
#  validation accuracy after  598  epochs :  70.79
#  validation accuracy after  599  epochs :  70.79
#  validation accuracy after  600  epochs :  70.79
#  validation accuracy after  601  epochs :  71.35
#  validation accuracy after  602  epochs :  71.35
#  validation accuracy after  603  epochs :  71.35
#  validation accuracy after  604  epochs :  71.35
#  validation accuracy after  605  epochs :  71.35
#  validation accuracy after  606  epochs :  71.35
#  validation accuracy after  607  epochs :  71.35
#  validation accuracy after  608  epochs :  71.35
#  validation accuracy after  609  epochs :  71.35
#  validation accuracy after  610  epochs :  71.35
#  validation accuracy after  611  epochs :  71.35
#  validation accuracy after  612  epochs :  71.35
#  validation accuracy after  613  epochs :  71.35
#  validation accuracy after  614  epochs :  71.35
#  validation accuracy after  615  epochs :  71.35
#  validation accuracy after  616  epochs :  71.35
#  validation accuracy after  617  epochs :  71.91
#  validation accuracy after  618  epochs :  73.60
#  validation accuracy after  619  epochs :  73.60
#  validation accuracy after  620  epochs :  73.60
#  validation accuracy after  621  epochs :  73.60
#  validation accuracy after  622  epochs :  73.60
#  validation accuracy after  623  epochs :  73.60
#  validation accuracy after  624  epochs :  73.60
#  validation accuracy after  625  epochs :  73.60
#  validation accuracy after  626  epochs :  73.60
#  validation accuracy after  627  epochs :  73.60
#  validation accuracy after  628  epochs :  73.60
#  validation accuracy after  629  epochs :  73.60
#  validation accuracy after  630  epochs :  73.60
#  validation accuracy after  631  epochs :  73.60
#  validation accuracy after  632  epochs :  73.60
#  validation accuracy after  633  epochs :  73.60
#  validation accuracy after  634  epochs :  73.03
#  validation accuracy after  635  epochs :  73.03
#  validation accuracy after  636  epochs :  73.03
#  validation accuracy after  637  epochs :  73.03
#  validation accuracy after  638  epochs :  73.03
#  validation accuracy after  639  epochs :  73.03
#  validation accuracy after  640  epochs :  73.03
#  validation accuracy after  641  epochs :  73.03
#  validation accuracy after  642  epochs :  73.03
#  validation accuracy after  643  epochs :  73.03
#  validation accuracy after  644  epochs :  73.03
#  validation accuracy after  645  epochs :  73.03
#  validation accuracy after  646  epochs :  73.03
#  validation accuracy after  647  epochs :  73.03
#  validation accuracy after  648  epochs :  73.03
#  validation accuracy after  649  epochs :  73.03
#  validation accuracy after  650  epochs :  73.03
#  validation accuracy after  651  epochs :  73.03
#  validation accuracy after  652  epochs :  73.03
#  validation accuracy after  653  epochs :  73.03
#  validation accuracy after  654  epochs :  73.03
#  validation accuracy after  655  epochs :  73.03
#  validation accuracy after  656  epochs :  73.03
#  validation accuracy after  657  epochs :  73.03
#  validation accuracy after  658  epochs :  73.03
#  validation accuracy after  659  epochs :  73.03
#  validation accuracy after  660  epochs :  73.03
#  validation accuracy after  661  epochs :  73.03
#  validation accuracy after  662  epochs :  73.03
#  validation accuracy after  663  epochs :  73.03
#  validation accuracy after  664  epochs :  74.16
#  validation accuracy after  665  epochs :  74.72
#  validation accuracy after  666  epochs :  74.72
#  validation accuracy after  667  epochs :  74.72
#  validation accuracy after  668  epochs :  75.84
#  validation accuracy after  669  epochs :  75.84
#  validation accuracy after  670  epochs :  75.84
#  validation accuracy after  671  epochs :  75.84
#  validation accuracy after  672  epochs :  75.84
#  validation accuracy after  673  epochs :  75.84
#  validation accuracy after  674  epochs :  75.84
#  validation accuracy after  675  epochs :  75.84
#  validation accuracy after  676  epochs :  75.84
#  validation accuracy after  677  epochs :  75.84
#  validation accuracy after  678  epochs :  75.84
#  validation accuracy after  679  epochs :  75.84
#  validation accuracy after  680  epochs :  75.84
#  validation accuracy after  681  epochs :  75.84
#  validation accuracy after  682  epochs :  75.84
#  validation accuracy after  683  epochs :  75.84
#  validation accuracy after  684  epochs :  75.84
#  validation accuracy after  685  epochs :  75.84
#  validation accuracy after  686  epochs :  75.84
#  validation accuracy after  687  epochs :  75.84
#  validation accuracy after  688  epochs :  75.84
#  validation accuracy after  689  epochs :  75.84
#  validation accuracy after  690  epochs :  75.84
#  validation accuracy after  691  epochs :  75.84
#  validation accuracy after  692  epochs :  75.84
#  validation accuracy after  693  epochs :  75.84
#  validation accuracy after  694  epochs :  75.84
#  validation accuracy after  695  epochs :  75.84
#  validation accuracy after  696  epochs :  75.84
#  validation accuracy after  697  epochs :  75.84
#  validation accuracy after  698  epochs :  75.84
#  validation accuracy after  699  epochs :  75.84
#  validation accuracy after  700  epochs :  75.84
#  validation accuracy after  701  epochs :  75.84
#  validation accuracy after  702  epochs :  75.84
#  validation accuracy after  703  epochs :  75.84
#  validation accuracy after  704  epochs :  75.84
#  validation accuracy after  705  epochs :  76.40
#  validation accuracy after  706  epochs :  76.40
#  validation accuracy after  707  epochs :  76.40
#  validation accuracy after  708  epochs :  76.40
#  validation accuracy after  709  epochs :  76.40
#  validation accuracy after  710  epochs :  76.40
#  validation accuracy after  711  epochs :  76.40
#  validation accuracy after  712  epochs :  76.40
#  validation accuracy after  713  epochs :  76.40
#  validation accuracy after  714  epochs :  76.40
#  validation accuracy after  715  epochs :  76.40
#  validation accuracy after  716  epochs :  76.40
#  validation accuracy after  717  epochs :  76.40
#  validation accuracy after  718  epochs :  76.40
#  validation accuracy after  719  epochs :  76.40
#  validation accuracy after  720  epochs :  76.40
#  validation accuracy after  721  epochs :  76.40
#  validation accuracy after  722  epochs :  76.40
#  validation accuracy after  723  epochs :  76.40
#  validation accuracy after  724  epochs :  76.40
#  validation accuracy after  725  epochs :  76.40
#  validation accuracy after  726  epochs :  76.40
#  validation accuracy after  727  epochs :  76.97
#  validation accuracy after  728  epochs :  76.97
#  validation accuracy after  729  epochs :  76.97
#  validation accuracy after  730  epochs :  77.53
#  validation accuracy after  731  epochs :  77.53
#  validation accuracy after  732  epochs :  77.53
#  validation accuracy after  733  epochs :  77.53
#  validation accuracy after  734  epochs :  77.53
#  validation accuracy after  735  epochs :  77.53
#  validation accuracy after  736  epochs :  77.53
#  validation accuracy after  737  epochs :  77.53
#  validation accuracy after  738  epochs :  77.53
#  validation accuracy after  739  epochs :  77.53
#  validation accuracy after  740  epochs :  77.53
#  validation accuracy after  741  epochs :  77.53
#  validation accuracy after  742  epochs :  77.53
#  validation accuracy after  743  epochs :  77.53
#  validation accuracy after  744  epochs :  77.53
#  validation accuracy after  745  epochs :  77.53
#  validation accuracy after  746  epochs :  77.53
#  validation accuracy after  747  epochs :  77.53
#  validation accuracy after  748  epochs :  77.53
#  validation accuracy after  749  epochs :  77.53
#  validation accuracy after  750  epochs :  77.53
#  validation accuracy after  751  epochs :  77.53
#  validation accuracy after  752  epochs :  77.53
#  validation accuracy after  753  epochs :  77.53
#  validation accuracy after  754  epochs :  77.53
#  validation accuracy after  755  epochs :  77.53
#  validation accuracy after  756  epochs :  77.53
#  validation accuracy after  757  epochs :  77.53
#  validation accuracy after  758  epochs :  77.53
#  validation accuracy after  759  epochs :  77.53
#  validation accuracy after  760  epochs :  77.53
#  validation accuracy after  761  epochs :  77.53
#  validation accuracy after  762  epochs :  77.53
#  validation accuracy after  763  epochs :  77.53
#  validation accuracy after  764  epochs :  77.53
#  validation accuracy after  765  epochs :  77.53
#  validation accuracy after  766  epochs :  77.53
#  validation accuracy after  767  epochs :  77.53
#  validation accuracy after  768  epochs :  77.53
#  validation accuracy after  769  epochs :  77.53
#  validation accuracy after  770  epochs :  77.53
#  validation accuracy after  771  epochs :  77.53
#  validation accuracy after  772  epochs :  77.53
#  validation accuracy after  773  epochs :  77.53
#  validation accuracy after  774  epochs :  77.53
#  validation accuracy after  775  epochs :  77.53
#  validation accuracy after  776  epochs :  77.53
#  validation accuracy after  777  epochs :  77.53
#  validation accuracy after  778  epochs :  77.53
#  validation accuracy after  779  epochs :  77.53
#  validation accuracy after  780  epochs :  77.53
#  validation accuracy after  781  epochs :  77.53
#  validation accuracy after  782  epochs :  77.53
#  validation accuracy after  783  epochs :  77.53
#  validation accuracy after  784  epochs :  77.53
#  validation accuracy after  785  epochs :  77.53
#  validation accuracy after  786  epochs :  77.53
#  validation accuracy after  787  epochs :  77.53
#  validation accuracy after  788  epochs :  77.53
#  validation accuracy after  789  epochs :  77.53
#  validation accuracy after  790  epochs :  77.53
#  validation accuracy after  791  epochs :  77.53
#  validation accuracy after  792  epochs :  77.53
#  validation accuracy after  793  epochs :  77.53
#  validation accuracy after  794  epochs :  77.53
#  validation accuracy after  795  epochs :  77.53
#  validation accuracy after  796  epochs :  77.53
#  validation accuracy after  797  epochs :  77.53
#  validation accuracy after  798  epochs :  77.53
#  validation accuracy after  799  epochs :  77.53
#  validation accuracy after  800  epochs :  77.53
#  validation accuracy after  801  epochs :  77.53
#  validation accuracy after  802  epochs :  77.53
#  validation accuracy after  803  epochs :  77.53
#  validation accuracy after  804  epochs :  77.53
#  validation accuracy after  805  epochs :  77.53
#  validation accuracy after  806  epochs :  77.53
#  validation accuracy after  807  epochs :  77.53
#  validation accuracy after  808  epochs :  77.53
#  validation accuracy after  809  epochs :  77.53
#  validation accuracy after  810  epochs :  77.53
#  validation accuracy after  811  epochs :  77.53
#  validation accuracy after  812  epochs :  77.53
#  validation accuracy after  813  epochs :  77.53
#  validation accuracy after  814  epochs :  78.65
#  validation accuracy after  815  epochs :  78.65
#  validation accuracy after  816  epochs :  78.65
#  validation accuracy after  817  epochs :  78.65
#  validation accuracy after  818  epochs :  78.65
#  validation accuracy after  819  epochs :  78.65
#  validation accuracy after  820  epochs :  78.65
#  validation accuracy after  821  epochs :  78.65
#  validation accuracy after  822  epochs :  78.65
#  validation accuracy after  823  epochs :  78.65
#  validation accuracy after  824  epochs :  78.65
#  validation accuracy after  825  epochs :  78.65
#  validation accuracy after  826  epochs :  78.65
#  validation accuracy after  827  epochs :  78.65
#  validation accuracy after  828  epochs :  78.65
#  validation accuracy after  829  epochs :  78.65
#  validation accuracy after  830  epochs :  78.65
#  validation accuracy after  831  epochs :  78.65
#  validation accuracy after  832  epochs :  79.21
#  validation accuracy after  833  epochs :  79.21
#  validation accuracy after  834  epochs :  79.21
#  validation accuracy after  835  epochs :  79.21
#  validation accuracy after  836  epochs :  79.21
#  validation accuracy after  837  epochs :  79.21
#  validation accuracy after  838  epochs :  79.21
#  validation accuracy after  839  epochs :  79.21
#  validation accuracy after  840  epochs :  79.21
#  validation accuracy after  841  epochs :  80.34
#  validation accuracy after  842  epochs :  80.34
#  validation accuracy after  843  epochs :  80.34
#  validation accuracy after  844  epochs :  80.34
#  validation accuracy after  845  epochs :  80.34
#  validation accuracy after  846  epochs :  80.34
#  validation accuracy after  847  epochs :  80.34
#  validation accuracy after  848  epochs :  80.34
#  validation accuracy after  849  epochs :  80.34
#  validation accuracy after  850  epochs :  80.34
#  validation accuracy after  851  epochs :  80.34
#  validation accuracy after  852  epochs :  80.34
#  validation accuracy after  853  epochs :  80.34
#  validation accuracy after  854  epochs :  80.34
#  validation accuracy after  855  epochs :  80.34
#  validation accuracy after  856  epochs :  80.34
#  validation accuracy after  857  epochs :  80.34
#  validation accuracy after  858  epochs :  80.34
#  validation accuracy after  859  epochs :  80.34
#  validation accuracy after  860  epochs :  80.34
#  validation accuracy after  861  epochs :  80.34
#  validation accuracy after  862  epochs :  80.34
#  validation accuracy after  863  epochs :  80.34
#  validation accuracy after  864  epochs :  80.34
#  validation accuracy after  865  epochs :  80.34
#  validation accuracy after  866  epochs :  80.34
#  validation accuracy after  867  epochs :  80.34
#  validation accuracy after  868  epochs :  80.34
#  validation accuracy after  869  epochs :  80.34
#  validation accuracy after  870  epochs :  80.34
#  validation accuracy after  871  epochs :  80.34
#  validation accuracy after  872  epochs :  80.34
#  validation accuracy after  873  epochs :  80.34
#  validation accuracy after  874  epochs :  80.34
#  validation accuracy after  875  epochs :  80.34
#  validation accuracy after  876  epochs :  80.34
#  validation accuracy after  877  epochs :  80.34
#  validation accuracy after  878  epochs :  80.34
#  validation accuracy after  879  epochs :  80.34
#  validation accuracy after  880  epochs :  80.34
#  validation accuracy after  881  epochs :  80.34
#  validation accuracy after  882  epochs :  80.34
#  validation accuracy after  883  epochs :  80.34
#  validation accuracy after  884  epochs :  80.34
#  validation accuracy after  885  epochs :  80.90
#  validation accuracy after  886  epochs :  80.90
#  validation accuracy after  887  epochs :  80.90
#  validation accuracy after  888  epochs :  80.90
#  validation accuracy after  889  epochs :  80.90
#  validation accuracy after  890  epochs :  80.90
#  validation accuracy after  891  epochs :  80.90
#  validation accuracy after  892  epochs :  80.90
#  validation accuracy after  893  epochs :  80.90
#  validation accuracy after  894  epochs :  80.90
#  validation accuracy after  895  epochs :  80.90
#  validation accuracy after  896  epochs :  80.90
#  validation accuracy after  897  epochs :  80.90
#  validation accuracy after  898  epochs :  80.90
#  validation accuracy after  899  epochs :  80.90
#  validation accuracy after  900  epochs :  80.90
#  validation accuracy after  901  epochs :  80.90
#  validation accuracy after  902  epochs :  80.90
#  validation accuracy after  903  epochs :  80.90
#  validation accuracy after  904  epochs :  80.90
#  validation accuracy after  905  epochs :  80.90
#  validation accuracy after  906  epochs :  80.90
#  validation accuracy after  907  epochs :  80.90
#  validation accuracy after  908  epochs :  80.90
#  validation accuracy after  909  epochs :  80.90
#  validation accuracy after  910  epochs :  80.90
#  validation accuracy after  911  epochs :  80.90
#  validation accuracy after  912  epochs :  80.90
#  validation accuracy after  913  epochs :  80.90
#  validation accuracy after  914  epochs :  80.90
#  validation accuracy after  915  epochs :  80.90
#  validation accuracy after  916  epochs :  80.90
#  validation accuracy after  917  epochs :  80.90
#  validation accuracy after  918  epochs :  80.90
#  validation accuracy after  919  epochs :  80.90
#  validation accuracy after  920  epochs :  80.90
#  validation accuracy after  921  epochs :  80.90
#  validation accuracy after  922  epochs :  80.90
#  validation accuracy after  923  epochs :  80.90
#  validation accuracy after  924  epochs :  80.90
#  validation accuracy after  925  epochs :  80.90
#  validation accuracy after  926  epochs :  80.90
#  validation accuracy after  927  epochs :  80.90
#  validation accuracy after  928  epochs :  80.90
#  validation accuracy after  929  epochs :  80.90
#  validation accuracy after  930  epochs :  80.90
#  validation accuracy after  931  epochs :  80.90
#  validation accuracy after  932  epochs :  80.90
#  validation accuracy after  933  epochs :  80.90
#  validation accuracy after  934  epochs :  80.90
#  validation accuracy after  935  epochs :  80.34
#  validation accuracy after  936  epochs :  80.34
#  validation accuracy after  937  epochs :  80.34
#  validation accuracy after  938  epochs :  80.34
#  validation accuracy after  939  epochs :  80.34
#  validation accuracy after  940  epochs :  80.34
#  validation accuracy after  941  epochs :  80.34
#  validation accuracy after  942  epochs :  80.34
#  validation accuracy after  943  epochs :  80.34
#  validation accuracy after  944  epochs :  80.34
#  validation accuracy after  945  epochs :  80.34
#  validation accuracy after  946  epochs :  80.34
#  validation accuracy after  947  epochs :  80.34
#  validation accuracy after  948  epochs :  80.34
#  validation accuracy after  949  epochs :  80.34
#  validation accuracy after  950  epochs :  80.34
#  validation accuracy after  951  epochs :  80.34
#  validation accuracy after  952  epochs :  80.34
#  validation accuracy after  953  epochs :  80.34
#  validation accuracy after  954  epochs :  80.34
#  validation accuracy after  955  epochs :  80.34
#  validation accuracy after  956  epochs :  80.34
#  validation accuracy after  957  epochs :  80.34
#  validation accuracy after  958  epochs :  80.34
#  validation accuracy after  959  epochs :  80.34
#  validation accuracy after  960  epochs :  80.34
#  validation accuracy after  961  epochs :  80.34
#  validation accuracy after  962  epochs :  80.34
#  validation accuracy after  963  epochs :  80.34
#  validation accuracy after  964  epochs :  80.34
#  validation accuracy after  965  epochs :  80.34
#  validation accuracy after  966  epochs :  80.34
#  validation accuracy after  967  epochs :  80.34
#  validation accuracy after  968  epochs :  80.34
#  validation accuracy after  969  epochs :  80.34
#  validation accuracy after  970  epochs :  80.34
#  validation accuracy after  971  epochs :  80.34
#  validation accuracy after  972  epochs :  80.34
#  validation accuracy after  973  epochs :  80.34
#  validation accuracy after  974  epochs :  80.34
#  validation accuracy after  975  epochs :  80.34
#  validation accuracy after  976  epochs :  80.34
#  validation accuracy after  977  epochs :  80.34
#  validation accuracy after  978  epochs :  80.34
#  validation accuracy after  979  epochs :  80.34
#  validation accuracy after  980  epochs :  80.34
# ...
#  validation accuracy after  4681  epochs :  83.71
#  validation accuracy after  4682  epochs :  83.71
#  validation accuracy after  4683  epochs :  83.71
#  validation accuracy after  4684  epochs :  83.71
#  validation accuracy after  4685  epochs :  83.71
#  validation accuracy after  4686  epochs :  83.71
#  validation accuracy after  4687  epochs :  83.71
#  validation accuracy after  4688  epochs :  83.71
#  validation accuracy after  4689  epochs :  83.71
#  validation accuracy after  4690  epochs :  83.71
#  validation accuracy after  4691  epochs :  83.71
#  validation accuracy after  4692  epochs :  83.71
#  validation accuracy after  4693  epochs :  83.71
#  validation accuracy after  4694  epochs :  83.71
#  validation accuracy after  4695  epochs :  83.71
#  validation accuracy after  4696  epochs :  83.71
#  validation accuracy after  4697  epochs :  83.71
#  validation accuracy after  4698  epochs :  83.71
#  validation accuracy after  4699  epochs :  83.71
#  validation accuracy after  4700  epochs :  83.71
#  validation accuracy after  4701  epochs :  83.71
#  validation accuracy after  4702  epochs :  83.71
#  validation accuracy after  4703  epochs :  83.71
#  validation accuracy after  4704  epochs :  83.71
#  validation accuracy after  4705  epochs :  83.71
#  validation accuracy after  4706  epochs :  83.71
#  validation accuracy after  4707  epochs :  83.71
#  validation accuracy after  4708  epochs :  83.71
#  validation accuracy after  4709  epochs :  83.71
#  validation accuracy after  4710  epochs :  83.71
#  validation accuracy after  4711  epochs :  83.71
#  validation accuracy after  4712  epochs :  83.71
#  validation accuracy after  4713  epochs :  83.71
#  validation accuracy after  4714  epochs :  83.71
#  validation accuracy after  4715  epochs :  83.71
#  validation accuracy after  4716  epochs :  83.71
#  validation accuracy after  4717  epochs :  83.71
#  validation accuracy after  4718  epochs :  83.71
#  validation accuracy after  4719  epochs :  83.71
#  validation accuracy after  4720  epochs :  83.71
#  validation accuracy after  4721  epochs :  83.71
#  validation accuracy after  4722  epochs :  83.71
#  validation accuracy after  4723  epochs :  83.71
#  validation accuracy after  4724  epochs :  83.71
#  validation accuracy after  4725  epochs :  83.71
#  validation accuracy after  4726  epochs :  83.71
#  validation accuracy after  4727  epochs :  83.71
#  validation accuracy after  4728  epochs :  83.71
#  validation accuracy after  4729  epochs :  83.71
#  validation accuracy after  4730  epochs :  83.71
#  validation accuracy after  4731  epochs :  83.71
#  validation accuracy after  4732  epochs :  83.71
#  validation accuracy after  4733  epochs :  83.71
#  validation accuracy after  4734  epochs :  83.71
#  validation accuracy after  4735  epochs :  83.71
#  validation accuracy after  4736  epochs :  83.71
#  validation accuracy after  4737  epochs :  83.71
#  validation accuracy after  4738  epochs :  83.71
#  validation accuracy after  4739  epochs :  83.71
#  validation accuracy after  4740  epochs :  83.71
#  validation accuracy after  4741  epochs :  83.71
#  validation accuracy after  4742  epochs :  83.71
#  validation accuracy after  4743  epochs :  83.71
#  validation accuracy after  4744  epochs :  83.71
#  validation accuracy after  4745  epochs :  83.71
#  validation accuracy after  4746  epochs :  83.71
#  validation accuracy after  4747  epochs :  83.71
#  validation accuracy after  4748  epochs :  83.71
#  validation accuracy after  4749  epochs :  83.71
#  validation accuracy after  4750  epochs :  83.71
#  validation accuracy after  4751  epochs :  83.71
#  validation accuracy after  4752  epochs :  83.71
#  validation accuracy after  4753  epochs :  83.71
#  validation accuracy after  4754  epochs :  83.71
#  validation accuracy after  4755  epochs :  83.71
#  validation accuracy after  4756  epochs :  83.71
#  validation accuracy after  4757  epochs :  83.71
#  validation accuracy after  4758  epochs :  84.27
#  validation accuracy after  4759  epochs :  84.27
#  validation accuracy after  4760  epochs :  84.27
#  validation accuracy after  4761  epochs :  84.27
#  validation accuracy after  4762  epochs :  84.27
#  validation accuracy after  4763  epochs :  84.27
#  validation accuracy after  4764  epochs :  84.27
#  validation accuracy after  4765  epochs :  84.27
#  validation accuracy after  4766  epochs :  84.27
#  validation accuracy after  4767  epochs :  84.27
#  validation accuracy after  4768  epochs :  84.27
#  validation accuracy after  4769  epochs :  84.27
#  validation accuracy after  4770  epochs :  84.27
#  validation accuracy after  4771  epochs :  84.27
#  validation accuracy after  4772  epochs :  84.27
#  validation accuracy after  4773  epochs :  84.27
#  validation accuracy after  4774  epochs :  84.27
#  validation accuracy after  4775  epochs :  84.27
#  validation accuracy after  4776  epochs :  84.27
#  validation accuracy after  4777  epochs :  84.27
#  validation accuracy after  4778  epochs :  84.27
#  validation accuracy after  4779  epochs :  84.27
#  validation accuracy after  4780  epochs :  84.27
#  validation accuracy after  4781  epochs :  84.27
#  validation accuracy after  4782  epochs :  84.27
#  validation accuracy after  4783  epochs :  84.27
#  validation accuracy after  4784  epochs :  84.27
#  validation accuracy after  4785  epochs :  84.27
#  validation accuracy after  4786  epochs :  84.27
#  validation accuracy after  4787  epochs :  84.27
#  validation accuracy after  4788  epochs :  84.27
#  validation accuracy after  4789  epochs :  84.27
#  validation accuracy after  4790  epochs :  84.27
#  validation accuracy after  4791  epochs :  84.27
#  validation accuracy after  4792  epochs :  84.27
#  validation accuracy after  4793  epochs :  84.27
#  validation accuracy after  4794  epochs :  84.27
#  validation accuracy after  4795  epochs :  84.27
#  validation accuracy after  4796  epochs :  84.27
#  validation accuracy after  4797  epochs :  84.27
#  validation accuracy after  4798  epochs :  84.27
#  validation accuracy after  4799  epochs :  84.27
#  validation accuracy after  4800  epochs :  84.27
#  validation accuracy after  4801  epochs :  84.27
#  validation accuracy after  4802  epochs :  84.27
#  validation accuracy after  4803  epochs :  84.27
#  validation accuracy after  4804  epochs :  84.27
#  validation accuracy after  4805  epochs :  84.27
#  validation accuracy after  4806  epochs :  84.27
#  validation accuracy after  4807  epochs :  84.27
#  validation accuracy after  4808  epochs :  84.27
#  validation accuracy after  4809  epochs :  84.27
#  validation accuracy after  4810  epochs :  84.27
#  validation accuracy after  4811  epochs :  84.27
#  validation accuracy after  4812  epochs :  84.27
#  validation accuracy after  4813  epochs :  84.27
#  validation accuracy after  4814  epochs :  84.27
#  validation accuracy after  4815  epochs :  84.27
#  validation accuracy after  4816  epochs :  84.27
#  validation accuracy after  4817  epochs :  84.27
#  validation accuracy after  4818  epochs :  84.27
#  validation accuracy after  4819  epochs :  84.27
#  validation accuracy after  4820  epochs :  84.27
#  validation accuracy after  4821  epochs :  84.27
#  validation accuracy after  4822  epochs :  84.27
#  validation accuracy after  4823  epochs :  84.27
#  validation accuracy after  4824  epochs :  84.27
#  validation accuracy after  4825  epochs :  84.27
#  validation accuracy after  4826  epochs :  84.27
#  validation accuracy after  4827  epochs :  84.27
#  validation accuracy after  4828  epochs :  84.27
#  validation accuracy after  4829  epochs :  84.27
#  validation accuracy after  4830  epochs :  84.27
#  validation accuracy after  4831  epochs :  84.27
#  validation accuracy after  4832  epochs :  84.27
#  validation accuracy after  4833  epochs :  84.27
#  validation accuracy after  4834  epochs :  84.27
#  validation accuracy after  4835  epochs :  84.27
#  validation accuracy after  4836  epochs :  84.27
#  validation accuracy after  4837  epochs :  84.27
#  validation accuracy after  4838  epochs :  84.27
#  validation accuracy after  4839  epochs :  84.27
#  validation accuracy after  4840  epochs :  84.27
#  validation accuracy after  4841  epochs :  84.27
#  validation accuracy after  4842  epochs :  84.27
#  validation accuracy after  4843  epochs :  84.27
#  validation accuracy after  4844  epochs :  84.27
#  validation accuracy after  4845  epochs :  84.27
#  validation accuracy after  4846  epochs :  84.27
#  validation accuracy after  4847  epochs :  84.27
#  validation accuracy after  4848  epochs :  84.27
#  validation accuracy after  4849  epochs :  84.27
#  validation accuracy after  4850  epochs :  84.27
#  validation accuracy after  4851  epochs :  84.27
#  validation accuracy after  4852  epochs :  84.27
#  validation accuracy after  4853  epochs :  84.27
#  validation accuracy after  4854  epochs :  84.27
#  validation accuracy after  4855  epochs :  84.27
#  validation accuracy after  4856  epochs :  84.27
#  validation accuracy after  4857  epochs :  84.27
#  validation accuracy after  4858  epochs :  84.27
#  validation accuracy after  4859  epochs :  84.27
#  validation accuracy after  4860  epochs :  84.27
#  validation accuracy after  4861  epochs :  84.27
#  validation accuracy after  4862  epochs :  84.27
#  validation accuracy after  4863  epochs :  84.27
#  validation accuracy after  4864  epochs :  84.27
#  validation accuracy after  4865  epochs :  84.27
#  validation accuracy after  4866  epochs :  84.27
#  validation accuracy after  4867  epochs :  84.27
#  validation accuracy after  4868  epochs :  84.27
#  validation accuracy after  4869  epochs :  84.27
#  validation accuracy after  4870  epochs :  84.27
#  validation accuracy after  4871  epochs :  84.27
#  validation accuracy after  4872  epochs :  84.27
#  validation accuracy after  4873  epochs :  84.27
#  validation accuracy after  4874  epochs :  84.27
#  validation accuracy after  4875  epochs :  84.27
#  validation accuracy after  4876  epochs :  84.27
#  validation accuracy after  4877  epochs :  84.27
#  validation accuracy after  4878  epochs :  84.27
#  validation accuracy after  4879  epochs :  84.27
#  validation accuracy after  4880  epochs :  84.27
#  validation accuracy after  4881  epochs :  84.27
#  validation accuracy after  4882  epochs :  84.27
#  validation accuracy after  4883  epochs :  84.27
#  validation accuracy after  4884  epochs :  84.27
#  validation accuracy after  4885  epochs :  84.27
#  validation accuracy after  4886  epochs :  84.27
#  validation accuracy after  4887  epochs :  84.27
#  validation accuracy after  4888  epochs :  84.27
#  validation accuracy after  4889  epochs :  84.27
#  validation accuracy after  4890  epochs :  84.27
#  validation accuracy after  4891  epochs :  84.27
#  validation accuracy after  4892  epochs :  84.27
#  validation accuracy after  4893  epochs :  84.27
#  validation accuracy after  4894  epochs :  84.27
#  validation accuracy after  4895  epochs :  84.27
#  validation accuracy after  4896  epochs :  84.27
#  validation accuracy after  4897  epochs :  84.27
#  validation accuracy after  4898  epochs :  84.27
#  validation accuracy after  4899  epochs :  84.27
#  validation accuracy after  4900  epochs :  84.27
#  validation accuracy after  4901  epochs :  84.27
#  validation accuracy after  4902  epochs :  84.27
#  validation accuracy after  4903  epochs :  84.27
#  validation accuracy after  4904  epochs :  84.27
#  validation accuracy after  4905  epochs :  84.27
#  validation accuracy after  4906  epochs :  84.27
#  validation accuracy after  4907  epochs :  84.27
#  validation accuracy after  4908  epochs :  84.27
#  validation accuracy after  4909  epochs :  84.27
#  validation accuracy after  4910  epochs :  84.27
#  validation accuracy after  4911  epochs :  84.27
#  validation accuracy after  4912  epochs :  84.27
#  validation accuracy after  4913  epochs :  84.27
#  validation accuracy after  4914  epochs :  84.27
#  validation accuracy after  4915  epochs :  84.27
#  validation accuracy after  4916  epochs :  84.27
#  validation accuracy after  4917  epochs :  84.27
#  validation accuracy after  4918  epochs :  84.27
#  validation accuracy after  4919  epochs :  84.27
#  validation accuracy after  4920  epochs :  84.27
#  validation accuracy after  4921  epochs :  84.27
#  validation accuracy after  4922  epochs :  84.27
#  validation accuracy after  4923  epochs :  84.27
#  validation accuracy after  4924  epochs :  84.27
#  validation accuracy after  4925  epochs :  84.27
#  validation accuracy after  4926  epochs :  84.27
#  validation accuracy after  4927  epochs :  84.27
#  validation accuracy after  4928  epochs :  84.27
#  validation accuracy after  4929  epochs :  84.27
#  validation accuracy after  4930  epochs :  84.27
#  validation accuracy after  4931  epochs :  84.27
#  validation accuracy after  4932  epochs :  84.27
#  validation accuracy after  4933  epochs :  84.27
#  validation accuracy after  4934  epochs :  84.27
#  validation accuracy after  4935  epochs :  84.27
#  validation accuracy after  4936  epochs :  84.27
#  validation accuracy after  4937  epochs :  84.27
#  validation accuracy after  4938  epochs :  84.27
#  validation accuracy after  4939  epochs :  84.27
#  validation accuracy after  4940  epochs :  84.27
#  validation accuracy after  4941  epochs :  84.27
#  validation accuracy after  4942  epochs :  84.27
#  validation accuracy after  4943  epochs :  84.27
#  validation accuracy after  4944  epochs :  84.27
#  validation accuracy after  4945  epochs :  84.27
#  validation accuracy after  4946  epochs :  84.27
#  validation accuracy after  4947  epochs :  84.27
#  validation accuracy after  4948  epochs :  84.27
#  validation accuracy after  4949  epochs :  84.27
#  validation accuracy after  4950  epochs :  84.27
#  validation accuracy after  4951  epochs :  84.27
#  validation accuracy after  4952  epochs :  84.27
#  validation accuracy after  4953  epochs :  84.27
#  validation accuracy after  4954  epochs :  84.27
#  validation accuracy after  4955  epochs :  84.27
#  validation accuracy after  4956  epochs :  84.27
#  validation accuracy after  4957  epochs :  84.27
#  validation accuracy after  4958  epochs :  84.27
#  validation accuracy after  4959  epochs :  84.27
#  validation accuracy after  4960  epochs :  84.27
#  validation accuracy after  4961  epochs :  84.27
#  validation accuracy after  4962  epochs :  84.27
#  validation accuracy after  4963  epochs :  84.27
#  validation accuracy after  4964  epochs :  84.27
#  validation accuracy after  4965  epochs :  84.27
#  validation accuracy after  4966  epochs :  84.27
#  validation accuracy after  4967  epochs :  84.27
#  validation accuracy after  4968  epochs :  84.27
#  validation accuracy after  4969  epochs :  84.27
#  validation accuracy after  4970  epochs :  84.27
#  validation accuracy after  4971  epochs :  84.27
#  validation accuracy after  4972  epochs :  84.27
#  validation accuracy after  4973  epochs :  84.27
#  validation accuracy after  4974  epochs :  84.27
#  validation accuracy after  4975  epochs :  84.27
#  validation accuracy after  4976  epochs :  84.27
#  validation accuracy after  4977  epochs :  84.27
#  validation accuracy after  4978  epochs :  84.27
#  validation accuracy after  4979  epochs :  84.27
#  validation accuracy after  4980  epochs :  84.27
#  validation accuracy after  4981  epochs :  84.27
#  validation accuracy after  4982  epochs :  84.27
#  validation accuracy after  4983  epochs :  84.27
#  validation accuracy after  4984  epochs :  84.27
#  validation accuracy after  4985  epochs :  84.27
#  validation accuracy after  4986  epochs :  84.27
#  validation accuracy after  4987  epochs :  84.27
#  validation accuracy after  4988  epochs :  84.27
#  validation accuracy after  4989  epochs :  84.27
#  validation accuracy after  4990  epochs :  84.27
#  validation accuracy after  4991  epochs :  84.27
#  validation accuracy after  4992  epochs :  84.27
#  validation accuracy after  4993  epochs :  84.27
#  validation accuracy after  4994  epochs :  84.27
#  validation accuracy after  4995  epochs :  84.27
#  validation accuracy after  4996  epochs :  84.27
#  validation accuracy after  4997  epochs :  84.27
#  validation accuracy after  4998  epochs :  84.27
#  validation accuracy after  4999  epochs :  84.27
#  validation accuracy after  5000  epochs :  84.27

# %%
# final evaluation on test data

temp = np.matmul(X_test, final_weights.T)
# define vectorized sigmoid
sigmoid_v = np.vectorize(sigmoid)
predicted_probability = sigmoid_v(temp)
    
prediction_temp = np.where(predicted_probability > 0.5, 1, predicted_probability)
prediction = np.where(prediction_temp <= 0.5, -1, prediction_temp)

    

accuracy = evaluate(prediction, Y_test)
print("Accuracy on the test data is ", accuracy)
# Out:
# Accuracy on the test data is  78.2122905027933

# %%
# Note 
# In this particular problem, increasing the learning rate value just leads to the model convergence in fewer epochs
# for example, with <0.01> as the learning rate value, the model converges in 4758 epochs -while 
# - with <0.025> as the learning rate value, the model converges in 1901 epochs
