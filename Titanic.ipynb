# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezash97/Machine-Learning-Course/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df = pd.read_csv('/content/titanicdata.csv')
df.head()
# Out:
#    Survived  Pclass  Sex   Age
# 0         0       3    2  22.0
# 1         1       1    1  38.0
# 2         1       3    1  26.0
# 3         1       1    1  35.0
# 4         0       3    2  35.0

# %%
X = df[["Pclass", "Sex", "Age"]].values
Y = df[["Survived"]]

# %%
import copy


def normalize(X, column_numbers):

  normalized_X = copy.copy(X)

  for column in column_numbers:

    selected_column = X[:, column]
    column_mean = np.mean(selected_column)
    column_std = np.std(selected_column)
    normalized_column = np.zeros(( selected_column.shape ))

    for  row_index, row in enumerate(selected_column):
      temp = ( row - column_mean) / column_std
      normalized_column[row_index] = temp


    normalized_column = normalized_column.reshape(normalized_column.shape[0])
    normalized_X[:, column] = normalized_column 

  
  return normalized_X

# %%
u = normalize(X, [0, 1, 2])
print(u[:5, :])
# Out:
# [[ 0.82737724  0.73769513 -0.5924806 ]
#  [-1.56610693 -1.35557354  0.63878901]
#  [ 0.82737724 -1.35557354 -0.2846632 ]
#  [-1.56610693 -1.35557354  0.40792596]
#  [ 0.82737724  0.73769513  0.40792596]]

# %%
def preprocess(X, column_numbers, Y):

  preprocessed_X = np.ones((X.shape[0], X.shape[1] + 1)) # + 1 for bias
  preprocessed_X[:, 1:] = normalize(X, column_numbers)

  preprocessed_Y = np.where(Y==0, -1, Y)

  
  return preprocessed_X, preprocessed_Y

# %%
X, Y = preprocess(X, [0, 1, 2], Y)
print(X[:5, :], X.shape)
print(Y[:5, :], Y.shape)
# Out:
# [[ 1.          0.82737724  0.73769513 -0.5924806 ]
#  [ 1.         -1.56610693 -1.35557354  0.63878901]
#  [ 1.          0.82737724 -1.35557354 -0.2846632 ]
#  [ 1.         -1.56610693 -1.35557354  0.40792596]
#  [ 1.          0.82737724  0.73769513  0.40792596]] (891, 4)
# [[-1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [-1]] (891, 1)

# %%
def sigmoid(s):
  
  return  1 / (1 + np.exp(-s))

# %%
def gradient_decent(X, Y, weights):
  
  # gradient_Ein = np.zeros((weight.shape))
  number_of_samples = X.shape[0]
  number_of_features = X.shape[1]
  full_shape_weight = np.zeros((X.shape))
  
  for i in range(number_of_samples):
    for j in range(number_of_features):
      full_shape_weight[i, j] = np.dot(Y[i], X[j, j]) / ( 1 + np.exp( np.dot( Y[i], np.matmul(X[i, :], weights.T) ) ) )

  gradient_Ein = ( (-1/number_of_samples) * np.sum(full_shape_weight, axis=0) ).reshape((1, number_of_features))


  return gradient_Ein

# %%
t = gradient_decent(X, Y, np.ones((1, 4)))
print(t.shape)
print(t)
# Out:
# (1, 4)
# [[ 0.28376502 -0.44440636 -0.38466435  0.11575512]]

# %%
def evaluate(predicted_y, actual_y):
  
  
  number_of_samples = actual_y.shape[0]
  TP, TN, FP, FN = 0, 0, 0, 0
  for i in range(number_of_samples):
    
    if actual_y[i] == 1 and predicted_y[i] == 1:
      TP += 1
    elif actual_y[i] == 1 and predicted_y[i] == -1:
      FN += 1
    elif actual_y[i] == -1 and predicted_y[i] == 1:
      FP += 1
    elif actual_y[i] == -1 and predicted_y[i] == -1:
      TN += 1
    else:
      pass

  return ( (TP + TN) / (TP + TN + FP + FN) ) * 100

# %%
def LogisticRegression(X, Y, X_validation, Y_validation, Learning_Rate, epoch_num):


  initial_weights = np.ones((1, X.shape[1]))
  number_of_samples = X.shape[0]
  weights = copy.copy(initial_weights)

  for i in range(epoch_num+1):
    
    # update
    weights -= (Learning_Rate * gradient_decent(X, Y, weights))
    
    # evaluate based on validation set
    temp = np.matmul(X, weights.T)
    # define vectorized sigmoid
    sigmoid_v = np.vectorize(sigmoid)
    predicted_probability = sigmoid_v(temp)
    
    prediction_temp = np.where(predicted_probability > 0.5, 1, predicted_probability)
    prediction = np.where(prediction_temp <= 0.5, -1, prediction_temp)

    

    accuracy = evaluate(prediction, Y)
    print(" Accuracy after ", i, " epochs : ", accuracy)

  return weights

# %%
p = LogisticRegression(X[:700, :], Y[:700, :], X[700:, :], Y[700:, :], 0.02, 1000)
# Out:
#  Accuracy after  0  epochs :  52.27272727272727
#  Accuracy after  1  epochs :  52.27272727272727
#  Accuracy after  2  epochs :  52.27272727272727
#  Accuracy after  3  epochs :  50.967741935483865
#  Accuracy after  4  epochs :  50.482315112540185
#  Accuracy after  5  epochs :  50.482315112540185
#  Accuracy after  6  epochs :  50.160771704180064
#  Accuracy after  7  epochs :  49.19614147909968
#  Accuracy after  8  epochs :  49.358974358974365
#  Accuracy after  9  epochs :  49.358974358974365
#  Accuracy after  10  epochs :  49.03846153846153
#  Accuracy after  11  epochs :  48.717948717948715
#  Accuracy after  12  epochs :  49.691358024691354
#  Accuracy after  13  epochs :  49.691358024691354
#  Accuracy after  14  epochs :  50.0
#  Accuracy after  15  epochs :  50.0
#  Accuracy after  16  epochs :  50.0
#  Accuracy after  17  epochs :  50.0
#  Accuracy after  18  epochs :  49.693251533742334
#  Accuracy after  19  epochs :  49.693251533742334
#  Accuracy after  20  epochs :  49.54128440366973
#  Accuracy after  21  epochs :  49.235474006116206
#  Accuracy after  22  epochs :  49.235474006116206
#  Accuracy after  23  epochs :  49.235474006116206
#  Accuracy after  24  epochs :  48.78048780487805
#  Accuracy after  25  epochs :  48.47560975609756
#  Accuracy after  26  epochs :  48.47560975609756
#  Accuracy after  27  epochs :  48.47560975609756
#  Accuracy after  28  epochs :  48.47560975609756
#  Accuracy after  29  epochs :  48.47560975609756
#  Accuracy after  30  epochs :  48.47560975609756
#  Accuracy after  31  epochs :  48.47560975609756
#  Accuracy after  32  epochs :  48.47560975609756
#  Accuracy after  33  epochs :  48.47560975609756
#  Accuracy after  34  epochs :  47.86585365853659
#  Accuracy after  35  epochs :  47.86585365853659
#  Accuracy after  36  epochs :  47.86585365853659
#  Accuracy after  37  epochs :  47.5609756097561
#  Accuracy after  38  epochs :  47.5609756097561
#  Accuracy after  39  epochs :  46.646341463414636
#  Accuracy after  40  epochs :  46.646341463414636
#  Accuracy after  41  epochs :  46.646341463414636
#  Accuracy after  42  epochs :  46.34146341463415
#  Accuracy after  172  epochs :  41.66666666666667
#  Accuracy after  173  epochs :  41.66666666666667
#  Accuracy after  174  epochs :  41.55844155844156
#  Accuracy after  175  epochs :  41.55844155844156
#  Accuracy after  176  epochs :  41.55844155844156
#  Accuracy after  177  epochs :  41.55844155844156
#  Accuracy after  178  epochs :  41.55844155844156
#  Accuracy after  179  epochs :  41.86046511627907
#  Accuracy after  180  epochs :  41.86046511627907
#  Accuracy after  181  epochs :  41.86046511627907
#  Accuracy after  182  epochs :  41.86046511627907
#  Accuracy after  183  epochs :  42.01030927835052
#  Accuracy after  184  epochs :  42.30769230769231
#  Accuracy after  185  epochs :  42.30769230769231
#  Accuracy after  186  epochs :  42.30769230769231
#  Accuracy after  187  epochs :  42.30769230769231
#  Accuracy after  188  epochs :  42.30769230769231
#  Accuracy after  189  epochs :  42.30769230769231
#  Accuracy after  190  epochs :  42.30769230769231
#  Accuracy after  191  epochs :  42.30769230769231
#  Accuracy after  192  epochs :  42.30769230769231
#  Accuracy after  193  epochs :  42.30769230769231
#  Accuracy after  194  epochs :  42.60204081632653
#  Accuracy after  195  epochs :  42.60204081632653
#  Accuracy after  196  epochs :  42.60204081632653
#  Accuracy after  197  epochs :  42.60204081632653
#  Accuracy after  198  epochs :  42.60204081632653
#  Accuracy after  199  epochs :  42.89340101522843
#  Accuracy after  200  epochs :  43.32493702770781
#  Accuracy after  201  epochs :  43.32493702770781
#  Accuracy after  202  epochs :  43.32493702770781
#  Accuracy after  203  epochs :  43.32493702770781
#  Accuracy after  204  epochs :  43.32493702770781
#  Accuracy after  205  epochs :  43.32493702770781
#  Accuracy after  206  epochs :  43.32493702770781
#  Accuracy after  207  epochs :  43.32493702770781
#  Accuracy after  208  epochs :  43.32493702770781
#  Accuracy after  209  epochs :  43.32493702770781
#  Accuracy after  210  epochs :  43.32493702770781
#  Accuracy after  211  epochs :  43.32493702770781
#  Accuracy after  212  epochs :  43.32493702770781
#  Accuracy after  213  epochs :  43.32493702770781
#  Accuracy after  214  epochs :  43.32493702770781
#  Accuracy after  215  epochs :  43.32493702770781
#  Accuracy after  216  epochs :  43.32493702770781
#  Accuracy after  217  epochs :  43.46733668341709
#  Accuracy after  218  epochs :  43.46733668341709
#  Accuracy after  219  epochs :  43.46733668341709
#  Accuracy after  220  epochs :  43.46733668341709
#  Accuracy after  221  epochs :  43.46733668341709
#  Accuracy after  222  epochs :  43.46733668341709
#  Accuracy after  223  epochs :  43.46733668341709
#  Accuracy after  224  epochs :  43.46733668341709
#  Accuracy after  225  epochs :  43.46733668341709
#  Accuracy after  226  epochs :  43.46733668341709
#  Accuracy after  227  epochs :  43.75
#  Accuracy after  228  epochs :  43.75
#  Accuracy after  229  epochs :  43.75
#  Accuracy after  230  epochs :  43.75
#  Accuracy after  231  epochs :  43.75
#  Accuracy after  232  epochs :  43.75
#  Accuracy after  233  epochs :  43.75
#  Accuracy after  234  epochs :  43.75
#  Accuracy after  235  epochs :  43.75
#  Accuracy after  236  epochs :  43.75
#  Accuracy after  237  epochs :  43.75
#  Accuracy after  238  epochs :  43.75
#  Accuracy after  239  epochs :  43.75
#  Accuracy after  240  epochs :  43.75
#  Accuracy after  241  epochs :  43.75
#  Accuracy after  242  epochs :  43.75
#  Accuracy after  243  epochs :  43.75
#  Accuracy after  244  epochs :  43.75
#  Accuracy after  245  epochs :  43.75
#  Accuracy after  246  epochs :  43.75
#  Accuracy after  247  epochs :  43.75
#  Accuracy after  248  epochs :  43.75
#  Accuracy after  249  epochs :  43.75
#  Accuracy after  250  epochs :  43.75
#  Accuracy after  251  epochs :  43.75
#  Accuracy after  252  epochs :  43.75
#  Accuracy after  253  epochs :  43.75
#  Accuracy after  254  epochs :  43.75
#  Accuracy after  255  epochs :  43.75
#  Accuracy after  256  epochs :  43.75
#  Accuracy after  257  epochs :  43.75
#  Accuracy after  258  epochs :  43.75
#  Accuracy after  259  epochs :  43.75
#  Accuracy after  260  epochs :  43.75
#  Accuracy after  261  epochs :  43.75
#  Accuracy after  262  epochs :  43.75
#  Accuracy after  263  epochs :  43.75
#  Accuracy after  264  epochs :  43.75
#  Accuracy after  265  epochs :  43.75
#  Accuracy after  266  epochs :  43.75
#  Accuracy after  267  epochs :  43.75
#  Accuracy after  268  epochs :  43.5
#  Accuracy after  269  epochs :  43.5
#  Accuracy after  270  epochs :  43.5
#  Accuracy after  271  epochs :  43.5
#  Accuracy after  272  epochs :  43.5
#  Accuracy after  273  epochs :  43.5
#  Accuracy after  274  epochs :  43.5
#  Accuracy after  275  epochs :  43.5
#  Accuracy after  276  epochs :  43.5
#  Accuracy after  277  epochs :  43.5
#  Accuracy after  278  epochs :  43.5
#  Accuracy after  279  epochs :  43.5
#  Accuracy after  280  epochs :  43.5
#  Accuracy after  281  epochs :  43.5
#  Accuracy after  282  epochs :  43.5
#  Accuracy after  283  epochs :  43.5
#  Accuracy after  284  epochs :  43.5
#  Accuracy after  285  epochs :  43.5
#  Accuracy after  286  epochs :  43.5
#  Accuracy after  287  epochs :  43.5
#  Accuracy after  288  epochs :  43.5
#  Accuracy after  289  epochs :  43.5
#  Accuracy after  290  epochs :  43.5
#  Accuracy after  291  epochs :  43.5
#  Accuracy after  292  epochs :  43.5
#  Accuracy after  293  epochs :  43.5
#  Accuracy after  294  epochs :  43.5
#  Accuracy after  295  epochs :  43.5
#  Accuracy after  296  epochs :  43.5
#  Accuracy after  297  epochs :  43.5
#  Accuracy after  298  epochs :  43.5
#  Accuracy after  299  epochs :  43.5
#  Accuracy after  300  epochs :  43.5
#  Accuracy after  301  epochs :  43.5
#  Accuracy after  302  epochs :  43.5
#  Accuracy after  303  epochs :  43.5
#  Accuracy after  304  epochs :  43.5
#  Accuracy after  305  epochs :  43.5
#  Accuracy after  306  epochs :  43.5
#  Accuracy after  307  epochs :  43.5
#  Accuracy after  308  epochs :  43.5
#  Accuracy after  309  epochs :  43.5
#  Accuracy after  310  epochs :  43.5
#  Accuracy after  311  epochs :  43.5
#  Accuracy after  312  epochs :  43.5
#  Accuracy after  313  epochs :  43.5
#  Accuracy after  314  epochs :  43.5
#  Accuracy after  315  epochs :  43.5
#  Accuracy after  316  epochs :  43.5
#  Accuracy after  317  epochs :  43.5
#  Accuracy after  318  epochs :  43.5
#  Accuracy after  319  epochs :  43.5
#  Accuracy after  320  epochs :  43.5
#  Accuracy after  321  epochs :  43.5
#  Accuracy after  322  epochs :  43.5
#  Accuracy after  323  epochs :  43.5
#  Accuracy after  324  epochs :  43.5
#  Accuracy after  325  epochs :  43.5
#  Accuracy after  326  epochs :  43.5
#  Accuracy after  327  epochs :  43.5
#  Accuracy after  328  epochs :  43.5
#  Accuracy after  329  epochs :  43.5
#  Accuracy after  330  epochs :  43.5
#  Accuracy after  331  epochs :  43.5
#  Accuracy after  332  epochs :  43.5
#  Accuracy after  333  epochs :  43.5
#  Accuracy after  334  epochs :  43.5
#  Accuracy after  335  epochs :  43.5
#  Accuracy after  336  epochs :  43.5
#  Accuracy after  337  epochs :  43.5
#  Accuracy after  338  epochs :  43.25
#  Accuracy after  339  epochs :  43.25
#  Accuracy after  340  epochs :  43.25
#  Accuracy after  341  epochs :  43.25
#  Accuracy after  342  epochs :  43.25
#  Accuracy after  343  epochs :  43.25
#  Accuracy after  344  epochs :  43.25
#  Accuracy after  345  epochs :  43.25
#  Accuracy after  346  epochs :  43.25
#  Accuracy after  347  epochs :  43.25
#  Accuracy after  348  epochs :  43.25
#  Accuracy after  349  epochs :  43.25
#  Accuracy after  350  epochs :  43.25
#  Accuracy after  351  epochs :  43.25
#  Accuracy after  352  epochs :  43.25
#  Accuracy after  353  epochs :  43.25
#  Accuracy after  354  epochs :  43.25
#  Accuracy after  355  epochs :  43.25
#  Accuracy after  356  epochs :  43.25
#  Accuracy after  357  epochs :  43.25
#  Accuracy after  358  epochs :  43.25
#  Accuracy after  359  epochs :  43.25
#  Accuracy after  360  epochs :  43.25
#  Accuracy after  361  epochs :  43.25
#  Accuracy after  362  epochs :  43.25
#  Accuracy after  363  epochs :  43.25
#  Accuracy after  364  epochs :  43.25
#  Accuracy after  365  epochs :  43.25
#  Accuracy after  366  epochs :  43.25
#  Accuracy after  367  epochs :  43.25
#  Accuracy after  368  epochs :  43.25
#  Accuracy after  369  epochs :  43.25
#  Accuracy after  370  epochs :  43.25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-287-957270b51517> in <module>()
# ----> 1 p = LogisticRegression(X[:700, :], Y[:700, :], X[700:, :], Y[700:, :], 0.02, 1000)
#
# <ipython-input-286-db902346183a> in LogisticRegression(X, Y, X_validation, Y_validation, Learning_Rate, epoch_num)
#      11
#      12     # update
# ---> 13     weights -= (Learning_Rate * gradient_decent(X, Y, weights))
#      14
#      15     # evaluate based on validation set
#
# <ipython-input-222-f75aacdaa645> in gradient_decent(X, Y, weights)
#       8   for i in range(number_of_samples):
#       9     for j in range(number_of_features):
# ---> 10       full_shape_weight[i, j] = np.dot(Y[i], X[j, j]) / ( 1 + np.exp( np.dot( Y[i], np.matmul(X[i, :], weights.T) ) ) )
#      11
#      12   gradient_Ein = ( (-1/number_of_samples) * np.sum(full_shape_weight, axis=0) ).reshape((1, number_of_features))
#
# KeyboardInterrupt:

# %%
print(p)
# Out:
# [[-0.55318403  3.43245226  3.10545517  0.36641592]]
